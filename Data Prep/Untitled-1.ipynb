# %%
print("Test Load")
import pandas as pd

raw_data = pd.read_excel("Testdata.xlsx")
print(raw_data)
# Out:
# Test Load
#                  Time         Outdoor          Unnamed: 2  \
# 0                 NaN  Temperature(℃)  Temperature Low(℃)
# 1    2024-09-01 01:00            11.5                11.2
# 2    2024-09-01 05:00            12.3                11.3
# 3    2024-09-01 09:00            13.5                12.7
# 4    2024-09-01 13:00            13.3                12.7
# ..                ...             ...                 ...
# 176  2024-09-30 05:00             9.3                 8.9
# 177  2024-09-30 09:00              10                 9.3
# 178  2024-09-30 13:00            11.1                10.4
# 179  2024-09-30 17:00            10.7                  10
# 180  2024-09-30 21:00             9.5                 8.9
#
#               Unnamed: 3     Unnamed: 4    Unnamed: 5   Unnamed: 6  \
# 0    Temperature High(℃)  Feels Like(℃)  Dew Point(℃)  Humidity(%)
# 1                   11.8           11.5          -0.2           78
# ...
